# %%
from catalyst_votingresults import CatalystVotingResults

# %% [markdown]
# # Choose a Fund among available files

# %%
CatalystVotingResults.FUNDS_FILES.keys()
# Out:
# dict_keys(['f3', 'f4', 'f5', 'f6', 'f7', 'f8'])

# %% [markdown]
# # Load the Voting Resuts from an specific Fund

# %%
fund = CatalystVotingResults('f5')

# %% [markdown]
# # @properties

# %% [markdown]
# ## Access the Fund Voting Result's structured data

# %%
fund.results
# Out:
#                   challenge  Budget                             Proposal  \
# 0       Developer ecosystem  600000         Testnet Cardanoscan Explorer
# 1       Developer ecosystem  600000   Cardano Rust SDK update for Alonzo
# 2       Developer ecosystem  600000            C# SDK for Blockfrost API
# 3       Developer ecosystem  600000                           Elixir SDK
# 4       Developer ecosystem  600000                       Cardano JS API
# ..                      ...     ...                                  ...
# 300  Sponsored by leftovers   92476  WADA +GL +Metadata = Donor Rewards+
# 301  Sponsored by leftovers   92476    Protocol for Social Media Storage
# 302  Sponsored by leftovers   92476  ADAvoice: Decentralized E-invoicing
# 303  Sponsored by leftovers   92476    Kitty Party 😺 DeFi Lending Circle
# 304  Sponsored by leftovers   92476  Mobile Plutus and Marlowe Dev Tools
#
#      SCORE        YES        NO  Unique Yes  Unique No     Result      STATUS  \
# ...

# %% [markdown]
# ## Access the Validation data set used for Challenge Budget information

# %%
fund.validation
# Out:
#                            challenge  budget
# 0                DApps&Integrations   250000
# 1                Developer ecosystem  600000
# 2        Distributed Decision Making  100000
# 3                  Proposer Outreach  100000
# 4          Catalyst Value Onboarding  100000
# 5                 Metadata challenge   50000
# 6          Grow Africa, Grow Cardano  250000
# 7  Scale-UP Cardano's DeFi Ecosystem  250000
# 8            Fund7 Challenge Setting  800000
# 9  Leftovers from regular challenges   92476

# %% [markdown]
# ## Get the available Fund Challenges

# %%
fund.challenges
# Out:
# ['Developer ecosystem',
#  'DApp&Integrations',
#  'Distributed decision making',
#  'Proposer Outreach',
#  'Catalyst Value Onboarding',
#  'Metadata challenge',
#  'Grow Africa, Grow Cardano wv',
#  'Scale-UP Cardanos DeFi Ecosyste',
#  'Fund7 Challenge Setting wv',
#  'Sponsored by leftovers']

# %% [markdown]
# # @Methods

# %% [markdown]
# ## Get the data from specific Challenges

# %%
fund.get_challenge_results(challenge=fund.challenges[0])
# Out:
#                                Proposal                     Link to ideascale  \
# 0          Testnet Cardanoscan Explorer  http://app.ideascale.com/t/UM5UZBivb
# 1    Cardano Rust SDK update for Alonzo  http://app.ideascale.com/t/UM5UZBitW
# 2             C# SDK for Blockfrost API  http://app.ideascale.com/t/UM5UZBiyB
# 3                            Elixir SDK  http://app.ideascale.com/t/UM5UZBiOH
# 4                        Cardano JS API  http://app.ideascale.com/t/UM5UZBiPS
# 5            Cardano Wallet Flutter SDK  http://app.ideascale.com/t/UM5UZBivs
# 6     Metadata oracle endpoint in Yoroi  http://app.ideascale.com/t/UM5UZBipP
# 7     Websocket link for Blockfrost API  http://app.ideascale.com/t/UM5UZBix4
# 8                               NFT Key  http://app.ideascale.com/t/UM5UZBilz
# 9               Cardano IPFS chronicles  http://app.ideascale.com/t/UM5UZBiyY
# 10             Glow Formal verification  http://app.ideascale.com/t/UM5UZBix7
# ...
