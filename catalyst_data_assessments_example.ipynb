# %%
from catalyst_data_assessments import CatalystAssessments

# %% [markdown]
# # Choose a Fund among available files

# %%
CatalystAssessments.FUNDS_FILES.keys()
# Out:
# dict_keys(['f3', 'f4', 'f5', 'f6', 'f7', 'f8'])

# %% [markdown]
# # Load the Voting Resuts from an specific Fund

# %%
fund = CatalystAssessments('f6')

# %% [markdown]
# # @properties

# %% [markdown]
# ## Access the Fund' Assessments structured data

# %%
fund.assessments
# Out:
#                   CA                       PROPOSAL_TITLE  CA_RATING  \
# 0     z_assessor_101     Design & Sim of Voting Influence   4.000000
# 1     z_assessor_101    Consenz: A Virtual Parliament App   3.333333
# 2     z_assessor_101    Catalyst Interactive News Journal   4.000000
# 3     z_assessor_101  Catalyst: Exploratory Data Analysis   5.000000
# 4     z_assessor_101  Community Tools Maintenance/Updates   5.000000
# ...              ...                                  ...        ...
# 5162   z_assessor_97   DeFi for Cardano - Learning Portal   5.000000
# 5163   z_assessor_99                          Remittances   2.333333
# 5164   z_assessor_99                    Proposer outreach   1.333333
# 5165   z_assessor_99               Multilingual resources   5.000000
# 5166   z_assessor_99        Improve and Grow Auditability   4.000000
#
#      QA_STATUS REASON   QA_CLASS
# 0        Valid  Valid  Excellent
# 1        Valid  Valid       Good
# 2        Valid  Valid       Good
# ...

# %% [markdown]
# ## Access the Fund's CAs

# %%
fund.cas
# Out:
#                 NUMBER_ASSESSMENTS    STATUS  \
# z_assessor_101                  11  Included
# z_assessor_104                   2  Excluded
# z_assessor_11                  275  Included
# z_assessor_113                  28  Included
# z_assessor_114                  16  Included
# ...                            ...       ...
# z_assessor_69                    7  Included
# z_assessor_78                   24  Included
# z_assessor_9                    18  Excluded
# z_assessor_97                    3  Excluded
# z_assessor_99                    8  Excluded
#
#                                            REASON
# z_assessor_101                           Included
# z_assessor_104  (Excluded) > 20% (Valid+Excluded)
# z_assessor_11                            Included
# z_assessor_113                           Included
# z_assessor_114                           Included
# ...                                           ...
# z_assessor_69                            Included
# ...

# %% [markdown]
# ## Access the Fund's vCAs

# %%
fund.vcas
# Out:
#                    NAME  NUMBER_REVIEWS  \
# 0        Andreas Sosilo             457
# 1     Antonio Pesqueira             433
# 2        AndrĂ© Diamond            1001
# 3         Andrew Penney             134
# 4       Tomi Astikainen            1159
# 5           Lester Mata             763
# 6          Bruno Mateus             861
# 7    Brigitte Democrite              70
# 8             Aldion Ka              20
# 9        Lucio Baglione             409
# 10        Thomas Farley             292
# 11            Tiger Duc             993
# 12            Phil Khoo              21
# 13    Filip BlagojeviÄ‡              26
# 14     Frederic Samvura              13
# 15    Leonardo Prasetyo              50
# 16   Giampiero Di Dieco            2546
# 17    Gaetan Chevallier            1811
# 18      Gagan Bharadwaj             299
# 19        Alex Teixeira             521
# 20        Hristo Kochev              33
# 21   Saiful Haq Bin Ali              67
# ...

# %% [markdown]
# # @Methods

# %% [markdown]
# ## Get the CAs' number of assessments by Assessments' QA Status

# %%
fund.get_ca_count_by_status()
# Out:
# QA_STATUS       Excluded  Valid
# CA
# z_assessor_101         0     11
# z_assessor_104         1      1
# z_assessor_11         16    259
# z_assessor_113         0     28
# z_assessor_114         1     15
# ...                  ...    ...
# z_assessor_69          0      7
# z_assessor_78          1     23
# z_assessor_9           4     14
# z_assessor_97          3      0
# z_assessor_99          8      0
#
# [437 rows x 2 columns]

# %% [markdown]
# ## Get the CAs' number of assessments by Assessments' QA Reason

# %%
fund.get_ca_count_by_reason()
# Out:
# REASON          Blank  Filtered Out  Valid
# CA
# z_assessor_101      0             0     11
# z_assessor_104      0             1      1
# z_assessor_11       9             7    259
# z_assessor_113      0             0     28
# z_assessor_114      1             0     15
# ...               ...           ...    ...
# z_assessor_69       0             0      7
# z_assessor_78       0             1     23
# z_assessor_9        4             0     14
# z_assessor_97       3             0      0
# z_assessor_99       4             4      0
#
# [437 rows x 3 columns]

# %% [markdown]
# ## Get the CAs' number of assessments by Assessments' QA Classification

# %%
fund.get_ca_count_by_class()
# Out:
# QA_CLASS        Excellent  Filtered Out  Good
# CA
# z_assessor_101          3             0     8
# z_assessor_104          0             1     1
# z_assessor_11           5             7   254
# z_assessor_113          2             0    26
# z_assessor_114          6             0     9
# ...                   ...           ...   ...
# z_assessor_68           0             0     6
# z_assessor_69           1             0     6
# z_assessor_78           4             1    19
# z_assessor_9            0             0    14
# z_assessor_99           0             4     0
#
# [317 rows x 3 columns]
